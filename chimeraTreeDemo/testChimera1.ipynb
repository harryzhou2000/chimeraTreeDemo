# %%
import chimeraTree2D
import meshBuilder
import matplotlib.pyplot as plt
import numpy as np

chimera = chimeraTree2D.ChimeraTree2D(h0=1 / 1024 * 1 / 2**4)

mesh, b = meshBuilder.buildMesh_tri_cylinder_gmsh([0, 0], 0.5, 0.8, 0.1, 0.04)
chimera.add_tri_mesh(chimeraTree2D.FGMesh(mesh, b))
mesh, b = meshBuilder.buildMesh_tri_cylinder_gmsh([1, 0], 0.5, 0.8, 0.1, 0.04)
chimera.add_tri_mesh(chimeraTree2D.FGMesh(mesh, b))

chimera.refine_meshB()


fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot()
# mesh.plot_grid(ax=ax)
chimera.meshB.plot_grid(ax=ax)

ax.axis("tight")
xc, yc = 0.5, 0
hsee = 1
ax.set_xlim([xc - hsee,xc + hsee])
ax.set_ylim([yc-hsee,yc + hsee])
ax.set_aspect(1)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Circle)
# Info    : [ 30%] Meshing curve 2 (Circle)
# Info    : [ 60%] Meshing curve 3 (Circle)
# Info    : [ 80%] Meshing curve 4 (Circle)
# Info    : Done meshing 1D (Wall 0.000205066s, CPU 0.000479s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00703351s, CPU 0.007539s)
# Info    : 388 nodes 779 elements
# Triangle 3
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Circle)
# Info    : [ 30%] Meshing curve 2 (Circle)
# Info    : [ 60%] Meshing curve 3 (Circle)
# Info    : [ 80%] Meshing curve 4 (Circle)
# Info    : Done meshing 1D (Wall 0.000197562s, CPU 0.000355s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0067781s, CPU 0.006835s)
# Info    : 393 nodes 789 elements
# Triangle 3
# here
# here
